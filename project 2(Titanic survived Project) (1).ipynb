# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\satyam\Desktop\Files-main\titanic_train.csv')
data.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape  #checking row and columns
# Out:
# (891, 13)

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
#parch has only zeros value we removed this column

# %%
data.drop(columns=['Unnamed: 0','PassengerId','Cabin','Name','Ticket',],axis=1,inplace=True) # droping unwanted column

# %%
data.head() #check column removed or not
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data.isna().sum()  #checking null values
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
#from above we observation that age and cabin ,embarked has null values in data set

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# checks data is balamced or not
data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# fill nan values
data['Embarked']=data['Embarked'].fillna(data['Embarked'].mode()[0])
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data.isna().sum()  #checking null values
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
data.info() # cheking data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
# we find all are intiger,intiger,and  float data

# %%
#separting numerical and categorical values
# for categorical
categorical=[]
for i in data.dtypes.index:
    if data.dtypes[i]=='object':
        categorical.append(i)
print('categorical=',categorical)
print('\n')
# for numerical
numerical=[]
for i in data.dtypes.index:
    if data.dtypes[i]!='object':
        numerical.append(i)
print('numerical=',numerical)
# Out:
# categorical= ['Sex', 'Embarked']
#
#
# numerical= ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# # Analysis (EDA)

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# cheking stats of dataset
# in the above observation we find some skewness in some column
# no null values present in data set
# there is huge difference between min and 25% thats mean there is outler present in dataset
# here is std is high in  ,Age,SibSp ,Parch ,Fare.

# %%
#cheking ditribution of plot
plt.figure(figsize=(15,10),facecolor='pink')
plotnumber=1
for column in numerical:
    if plotnumber<=6:
        plt.subplot(2,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
data.skew()
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# dtype: float64

# %%
#cheking ditribution of plot
plt.figure(figsize=(10,10),facecolor='pink')
plotnumber=1
for column in numerical:     # we checks for continous data
    if plotnumber<=6:
        plt.subplot(2,3,plotnumber)
        sns.boxplot(data=data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
# here fare ,parch,sibsp and age has some outliers

# %% [markdown]
# # finding IQR to identify outliers

# %%
# 1st quantile
q1=data.quantile(0.25)

# 3rd quantile
q3=data.quantile(0.75)
iqr=q3-q1

# %%
iqr
# Out:
# Survived     1.0000
# Pclass       1.0000
# Age         13.0000
# SibSp        1.0000
# Parch        0.0000
# Fare        23.0896
# dtype: float64

# %% [markdown]
# # Removing outliers for age and fare bcz these are continious column

# %%
Age_high=(q3['Age'] +(1.5*iqr['Age']))  #checking  validating or outlier 
print(Age_high)
a=np.where(data['Age']>Age_high)      # cheking index of outliers
data=data.drop(data.index[a])                         # drop the index which where found outliers
print(data.shape)

data.reset_index()
# Out:
# 54.5
# (849, 8)
#      index  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0        0         0       3    male  22.000000      1      0   7.2500
# 1        1         1       1  female  38.000000      1      0  71.2833
# 2        2         1       3  female  26.000000      0      0   7.9250
# 3        3         1       1  female  35.000000      1      0  53.1000
# 4        4         0       3    male  35.000000      0      0   8.0500
# ..     ...       ...     ...     ...        ...    ...    ...      ...
# 844    886         0       2    male  27.000000      0      0  13.0000
# 845    887         1       1  female  19.000000      0      0  30.0000
# 846    888         0       3  female  29.699118      1      2  23.4500
# 847    889         1       1    male  26.000000      0      0  30.0000
# 848    890         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 844        S
# 845        S
# 846        S
# 847        C
# 848        Q
#
# [849 rows x 9 columns]

# %%
# for low side
Age_low=(q1['Age'] - (1.5*iqr['Age']))  # for low side 
print(Age_low)
a=np.where(data['Age']<Age_low)      # cheking index of outliers
data=data.drop(data.index[a])                         # drop the index which where found outliers
print(data.shape)

data.reset_index()
# Out:
# 2.5
# (825, 8)
#      index  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0        0         0       3    male  22.000000      1      0   7.2500
# 1        1         1       1  female  38.000000      1      0  71.2833
# 2        2         1       3  female  26.000000      0      0   7.9250
# 3        3         1       1  female  35.000000      1      0  53.1000
# 4        4         0       3    male  35.000000      0      0   8.0500
# ..     ...       ...     ...     ...        ...    ...    ...      ...
# 820    886         0       2    male  27.000000      0      0  13.0000
# 821    887         1       1  female  19.000000      0      0  30.0000
# 822    888         0       3  female  29.699118      1      2  23.4500
# 823    889         1       1    male  26.000000      0      0  30.0000
# 824    890         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 820        S
# 821        S
# 822        S
# 823        C
# 824        Q
#
# [825 rows x 9 columns]

# %%
SibSp_high=(q3['SibSp'] +(1.5*iqr['SibSp']))  #checking  validating or outlier 
print(SibSp_high)
a=np.where(data['SibSp']>SibSp_high)      # cheking index of outliers
data=data.drop(data.index[a])                         # drop the index which where found outliers
print(data.shape)

data.reset_index()
# Out:
# 2.5
# (786, 8)
#      index  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0        0         0       3    male  22.000000      1      0   7.2500
# 1        1         1       1  female  38.000000      1      0  71.2833
# 2        2         1       3  female  26.000000      0      0   7.9250
# 3        3         1       1  female  35.000000      1      0  53.1000
# 4        4         0       3    male  35.000000      0      0   8.0500
# ..     ...       ...     ...     ...        ...    ...    ...      ...
# 781    886         0       2    male  27.000000      0      0  13.0000
# 782    887         1       1  female  19.000000      0      0  30.0000
# 783    888         0       3  female  29.699118      1      2  23.4500
# 784    889         1       1    male  26.000000      0      0  30.0000
# 785    890         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 781        S
# 782        S
# 783        S
# 784        C
# 785        Q
#
# [786 rows x 9 columns]

# %%
Parch_high=(q3['Parch'] +(1.5*iqr['Parch']))  #checking  validating or outlier 
print(Parch_high)
a=np.where(data['Parch']>Parch_high)      # cheking index of outliers
data=data.drop(data.index[a])                         # drop the index which where found outliers
print(data.shape)

data.reset_index()
# Out:
# 0.0
# (642, 8)
#      index  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 637    884         0       3    male  25.0      0      0   7.0500        S
# 638    886         0       2    male  27.0      0      0  13.0000        S
# 639    887         1       1  female  19.0      0      0  30.0000        S
# 640    889         1       1    male  26.0      0      0  30.0000        C
# 641    890         0       3    male  32.0      0      0   7.7500        Q
#
# [642 rows x 9 columns]

# %%
Fare_high=(q3['Fare'] +(1.5*iqr['Fare']))  #checking  validating or outlier 
print(Fare_high)
a=np.where(data['Fare']>Fare_high)      # cheking index of outliers
data=data.drop(data.index[a])                         # drop the index which where found outliers
print(data.shape)

data.reset_index()
# Out:
# 65.6344
# (577, 8)
#      index  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0        0         0       3    male  22.000000      1      0   7.2500
# 1        2         1       3  female  26.000000      0      0   7.9250
# 2        3         1       1  female  35.000000      1      0  53.1000
# 3        4         0       3    male  35.000000      0      0   8.0500
# 4        5         0       3    male  29.699118      0      0   8.4583
# ..     ...       ...     ...     ...        ...    ...    ...      ...
# 572    884         0       3    male  25.000000      0      0   7.0500
# 573    886         0       2    male  27.000000      0      0  13.0000
# 574    887         1       1  female  19.000000      0      0  30.0000
# 575    889         1       1    male  26.000000      0      0  30.0000
# 576    890         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          S
# 2          S
# 3          S
# 4          Q
# ..       ...
# 572        S
# 573        S
# 574        S
# 575        C
# 576        Q
#
# [577 rows x 9 columns]

# %%
#cheking ditribution of plot
plt.figure(figsize=(15,20),facecolor='pink')
plotnumber=1
for column in numerical:
    if plotnumber<=11:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
#removing parch bcz it has zeoes valies if we romve multicollinearty problem

# %%
data.drop(columns=['Parch'],inplace=True)

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=oe.fit_transform(data[i].values.reshape(-1,1))
data
# Out:
#      Survived  Pclass  Sex        Age  SibSp     Fare  Embarked
# 0           0       3  1.0  22.000000      1   7.2500       2.0
# 2           1       3  0.0  26.000000      0   7.9250       2.0
# 3           1       1  0.0  35.000000      1  53.1000       2.0
# 4           0       3  1.0  35.000000      0   8.0500       2.0
# 5           0       3  1.0  29.699118      0   8.4583       1.0
# ..        ...     ...  ...        ...    ...      ...       ...
# 884         0       3  1.0  25.000000      0   7.0500       2.0
# 886         0       2  1.0  27.000000      0  13.0000       2.0
# 887         1       1  0.0  19.000000      0  30.0000       2.0
# 889         1       1  1.0  26.000000      0  30.0000       0.0
# 890         0       3  1.0  32.000000      0   7.7500       1.0
#
# [577 rows x 7 columns]

# %%
# separating features and label
x=data.drop(columns=['Survived'])
y=data['Survived']

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp     Fare  Embarked
# 0         3  1.0  22.000000      1   7.2500       2.0
# 2         3  0.0  26.000000      0   7.9250       2.0
# 3         1  0.0  35.000000      1  53.1000       2.0
# 4         3  1.0  35.000000      0   8.0500       2.0
# 5         3  1.0  29.699118      0   8.4583       1.0
# ..      ...  ...        ...    ...      ...       ...
# 884       3  1.0  25.000000      0   7.0500       2.0
# 886       2  1.0  27.000000      0  13.0000       2.0
# 887       1  0.0  19.000000      0  30.0000       2.0
# 889       1  1.0  26.000000      0  30.0000       0.0
# 890       3  1.0  32.000000      0   7.7500       1.0
#
# [577 rows x 6 columns]

# %%
y
# Out:
# 0      0
# 2      1
# 3      1
# 4      0
# 5      0
#       ..
# 884    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 577, dtype: int64

# %% [markdown]
# # cheking relation between features vs label

# %%
plt.figure(figsize=(15,20))
plotnumber=1
for column in x:
    if plotnumber<=7:
        plt.subplot(3,3,plotnumber)
        sns.stripplot(y,x[column])
    plotnumber+=1
plt.show()

# %% [markdown]
# # checks multicollinearity problem,and checks relation features vs features

# %%
#dtandardaeize the data for remove biasness
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled.shape[1]
# Out:
# 6

# %%
#cheking correlation betwen features vs features
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range  (x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif  features
# 0  2.036037    Pclass
# 1  1.058109       Sex
# 2  1.161012       Age
# 3  1.230376     SibSp
# 4  2.164724      Fare
# 5  1.018847  Embarked

# %%
# if vif grater than 5 in this data then there is multicollinearity problem¶

# %%
#training the data
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=355)

# %% [markdown]
# # pre-processing steps completed¶

# %% [markdown]
# # model buliding

# %%
#write one funtion and call as many as time to check accuracy score of different model
def metric_score(dt,x_train,x_test,y_train,y_test, train=True):
    if train:
        y_pred=dt.predict(x_train)
        
        print('\n========== Train Result========')
        print(f'Accuracy score: {accuracy_score(y_train,y_pred)*100:.2f}%')
        
    elif train==False:
    
        pred=dt.predict(x_test)
        
        print('\n========== Test Result========')
        print(f'Accuracy score: {accuracy_score(y_test,pred)*100:.2f}%')

        print('\n\n Test classification Report\n',classification_report(y_test,pred,digits=2))

# %%
#model buliding
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # model accuracy

# %%
#calling function
metric_score(dt,x_train,x_test,y_train,y_test, train=True)
metric_score(dt,x_train,x_test,y_train,y_test, train=False)
# Out:
# ========== Train Result========
# Accuracy score: 97.22%
#
# ========== Test Result========
# Accuracy score: 74.48%
#
#
#  Test classification Report
#                precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82       105
#            1       0.54      0.53      0.53        40
#
#     accuracy                           0.74       145
#    macro avg       0.68      0.68      0.68       145
# weighted avg       0.74      0.74      0.74       145

# %% [markdown]
# # cheking some prediction

# %%
data.head(2)
# Out:
#    Survived  Pclass  Sex   Age  SibSp   Fare  Embarked
# 0         0       3  1.0  22.0      1  7.250       2.0
# 2         1       3  0.0  26.0      0  7.925       2.0

# %%
#since we have already fit ,now we have only to transform data
print('survived or not: ',dt.predict(scaler.transform([[3,1.0,22.0,1,7.250,2.0]])))
# Out:
# survived or not:  [0]

# %% [markdown]
# # model buliding compeleted
